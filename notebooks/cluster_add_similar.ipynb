# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
import pyarrow as pa
import multiprocessing

# %%
#in_memory_stream = pa.input_stream('/home/lyg/data/pubchem/arrow/pubchem_sorted.arrow')
#opened_stream = pa.ipc.open_stream(in_memory_stream)
#table = opened_stream.read_all()

table = pa.ipc.RecordBatchFileReader(pa.memory_map('/home/lyg/data/pubchem/arrow/pubchem_best.arrow')).read_all()

smiles = table.column('smiles').to_pylist()

smiles[0]
# Out:
# 'N'

# %%
radius=2
nBits=2048

mfpgen = rdFingerprintGenerator.GetMorganGenerator(radius=radius,fpSize=nBits)

def smiles_to_fp(smiles):
  """
  Worker function to create an RDKit fingerprint from a SMILES string.
  """
  mol = Chem.MolFromSmiles(smiles)
  if mol is None:
    # return an empty fingerprint if the SMILES is invalid
    return DataStructs.cDataStructs.ExplicitBitVect(nBits)
  else:
    return mfpgen.GetFingerprint(mol)

with multiprocessing.Pool() as pool:
    arr = pool.map(smiles_to_fp, smiles)
# Out:
# [09:47:33] Explicit valence for atom # 0 B, 4, is greater than permitted
# [09:47:34] Explicit valence for atom # 2 O, 2, is greater than permitted
# [09:47:34] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [09:47:35] Explicit valence for atom # 0 B, 4, is greater than permitted
# [09:47:35] Explicit valence for atom # 0 B, 4, is greater than permitted
# [09:47:36] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [09:47:37] Conflicting single bond directions around double bond at index 6.
# [09:47:37]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:37] Explicit valence for atom # 10 O, 2, is greater than permitted
# [09:47:37] Conflicting single bond directions around double bond at index 3.
# [09:47:37]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:38] Conflicting single bond directions around double bond at index 8.
# [09:47:38]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:38] Conflicting single bond directions around double bond at index 8.
# [09:47:38]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:38] Conflicting single bond directions around double bond at index 7.
# [09:47:38]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:40] Conflicting single bond directions around double bond at index 3.
# [09:47:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:41] Conflicting single bond directions around double bond at index 3.
# [09:47:41]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:42] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [09:47:42] Conflicting single bond directions around double bond at index 12.
# [09:47:42]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:46] Conflicting single bond directions around double bond at index 3.
# [09:47:46]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:47] Conflicting single bond directions around double bond at index 6.
# [09:47:47]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:50] Conflicting single bond directions around double bond at index 3.
# [09:47:50]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:51] Conflicting single bond directions around double bond at index 1.
# [09:47:51]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:52] Conflicting single bond directions around double bond at index 3.
# [09:47:52]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:52] Conflicting single bond directions around double bond at index 5.
# [09:47:52]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:55] Conflicting single bond directions around double bond at index 14.
# [09:47:55]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:56] Conflicting single bond directions around double bond at index 7.
# [09:47:56]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:59] Conflicting single bond directions around double bond at index 13.
# [09:47:59]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:47:59] Conflicting single bond directions around double bond at index 3.
# [09:47:59]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:48:01] Conflicting single bond directions around double bond at index 7.
# [09:48:01]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:48:11] Conflicting single bond directions around double bond at index 7.
# [09:48:11]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:48:16] Conflicting single bond directions around double bond at index 14.
# [09:48:16]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:48:51] Conflicting single bond directions around double bond at index 5.
# [09:48:51]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:48:51] Conflicting single bond directions around double bond at index 4.
# [09:48:51]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:48:52] Conflicting single bond directions around double bond at index 14.
# [09:48:52]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:48:59] Conflicting single bond directions around double bond at index 6.
# [09:48:59]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:11] Conflicting single bond directions around double bond at index 13.
# [09:49:11]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:22] Conflicting single bond directions around double bond at index 6.
# [09:49:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:25] Conflicting single bond directions around double bond at index 2.
# [09:49:25]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:30] Conflicting single bond directions around double bond at index 24.
# [09:49:30]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:34] Conflicting single bond directions around double bond at index 16.
# [09:49:34]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:34] Conflicting single bond directions around double bond at index 5.
# [09:49:34]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:35] Conflicting single bond directions around double bond at index 5.
# [09:49:35]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:38] Conflicting single bond directions around double bond at index 10.
# [09:49:38]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:49:50] Conflicting single bond directions around double bond at index 27.
# [09:49:50]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:00] Conflicting single bond directions around double bond at index 29.
# [09:50:00]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:00] Conflicting single bond directions around double bond at index 9.
# [09:50:00]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:02] Conflicting single bond directions around double bond at index 19.
# [09:50:02]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:04] Conflicting single bond directions around double bond at index 11.
# [09:50:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:05] Conflicting single bond directions around double bond at index 17.
# [09:50:05]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:05] Conflicting single bond directions around double bond at index 11.
# [09:50:05]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:05] Conflicting single bond directions around double bond at index 11.
# [09:50:05]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:05] Conflicting single bond directions around double bond at index 11.
# [09:50:05]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:07] Conflicting single bond directions around double bond at index 3.
# [09:50:07]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:10] Conflicting single bond directions around double bond at index 11.
# [09:50:10]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:14] Conflicting single bond directions around double bond at index 12.
# [09:50:14]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:14] Conflicting single bond directions around double bond at index 17.
# [09:50:14]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:17] Conflicting single bond directions around double bond at index 17.
# [09:50:17]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:17] Conflicting single bond directions around double bond at index 11.
# [09:50:17]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:20] Conflicting single bond directions around double bond at index 11.
# [09:50:20]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:20] Conflicting single bond directions around double bond at index 11.
# [09:50:20]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:20] Conflicting single bond directions around double bond at index 11.
# [09:50:20]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:21] Conflicting single bond directions around double bond at index 11.
# [09:50:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:21] Conflicting single bond directions around double bond at index 11.
# [09:50:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:22] Conflicting single bond directions around double bond at index 11.
# [09:50:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:24] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [09:50:41] Conflicting single bond directions around double bond at index 11.
# [09:50:41]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:42] Conflicting single bond directions around double bond at index 13.
# [09:50:42]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:43] Conflicting single bond directions around double bond at index 11.
# [09:50:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:43] Conflicting single bond directions around double bond at index 11.
# [09:50:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:44] Conflicting single bond directions around double bond at index 11.
# [09:50:44]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:44] Conflicting single bond directions around double bond at index 11.
# [09:50:44]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:46] Conflicting single bond directions around double bond at index 11.
# [09:50:46]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:46] Conflicting single bond directions around double bond at index 11.
# [09:50:46]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [09:50:54] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [09:51:25] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.

# %%
assert len(arr) == len(smiles) == table.num_rows

# %%
# read in /home/lyg/data/pubchem/arrow/pubchem_best_cluster_picks.txt into a list
with open('/home/lyg/data/pubchem/arrow/pubchem_best_cluster_picks_raw.txt', 'r') as f:
    picks = [int(line.strip()) for line in f]

# %%
def find_similar_index(args):
    pick_idx, pick_fp, pick_num_atoms, arr, num_atoms_arr = args
    lower = pick_num_atoms * 0.83
    upper = pick_num_atoms * 1.17
    for idx, fp in enumerate(arr):
        if idx == pick_idx:
            continue
        num_atoms = num_atoms_arr[idx]
        if not (lower <= num_atoms <= upper):
            continue
        sim = DataStructs.TanimotoSimilarity(pick_fp, fp)
        if 0.45 <= sim < 0.65:
            return idx
    return None

num_atoms_arr = table['num_atoms'].to_pylist()
args_list = [(pick_idx, arr[pick_idx], num_atoms_arr[pick_idx], arr, num_atoms_arr) for pick_idx in picks]

with multiprocessing.Pool(processes=3) as pool:
    similar_indices = pool.map(find_similar_index, args_list)

# Remove None values and keep only found indices
similar_indices = [idx for idx in similar_indices if idx is not None]
merged = list(set(picks + similar_indices))

# %%
table.column_names
# Out:
# ['cid',
#  'complexity',
#  'hba',
#  'hbd',
#  'rotatable_bonds',
#  'tpsa',
#  'logp',
#  'monoisotopic_mass',
#  'exact_mass',
#  'formula',
#  'molecular_weight',
#  'charge',
#  'num_atoms',
#  'num_def_stereo',
#  'num_undef_stereo',
#  'num_def_double',
#  'num_undef_double',
#  'num_isotopic_atoms',
#  'fragments',
#  'num_tautomers',
#  'num_complexity',
#  'iupac_openeye',
#  'iupac_cas',
#  'iupac',
#  'iupac_systematic',
#  'iupac_traditional',
#  'smiles',
#  'split']

# %%
# with open('cluster_labels.txt', 'w') as f:
#     for i in picks:
#         smiles = table['smiles'][i].as_py()
#         iupac = table['iupac'][i].as_py()
#         cid = table['cid'][i].as_py()
#         formula = table['formula'][i].as_py()
#         num_atoms = table['num_atoms'][i].as_py()
#         # f.write(f"{smiles}\t{iupac}\t{labels[i]}\n")
#         f.write(f"{cid}\t{smiles}\t{iupac}\t{formula}\t{num_atoms}\n")

def convert_string_view_to_string(table):
    for column in table.schema:
        if pa.types.is_string_view(column.type):
            # Recreate the column as pa.string
            table = table.set_column(
                table.schema.get_field_index(column.name),
                column.name,
                pa.array(table[column.name].to_pylist(), type=pa.string())
            )
    return table

table2 = table.take(pa.array(merged))

# huggingface only supports string, not string_view
table2 = convert_string_view_to_string(table2)

with pa.OSFile('/home/lyg/data/pubchem/arrow/pubchem_best_cluster_similar.arrow', 'wb') as sink:
    with pa.RecordBatchFileWriter(sink, table2.schema) as writer:
        writer.write_table(table2)
print(f"Finished writing {len(table2)} picks to pubchem_best_cluster_similar.arrow")
# Out:
# Finished writing 474603 picks to pubchem_best_cluster_similar.arrow

# %%
with open('/home/lyg/data/pubchem/arrow/pubchem_best_cluster_similar_picks.txt', 'w') as f:   
    for i in merged:
        f.write(f"{i}\n")
