# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdFingerprintGenerator
import numpy as np
import hdbscan
import pyarrow as pa
from rdkit.SimDivFilters import rdSimDivPickers
import multiprocessing

# %%
#in_memory_stream = pa.input_stream('/home/lyg/data/pubchem/arrow/pubchem_sorted.arrow')
#opened_stream = pa.ipc.open_stream(in_memory_stream)
#table = opened_stream.read_all()

table = pa.ipc.RecordBatchFileReader(pa.memory_map('/home/lyg/data/pubchem/arrow/pubchem_best.arrow')).read_all()

# write out the smiles to a temporary file
smiles = table.column('smiles').to_pylist()

smiles[0]
# Out:
# '[C-]#[O+]'

# %%
radius=2
nBits=2048

mfpgen = rdFingerprintGenerator.GetMorganGenerator(radius=radius,fpSize=nBits)

def smiles_to_fp(smiles):
  """
  Worker function to create an RDKit fingerprint from a SMILES string.
  """
  mol = Chem.MolFromSmiles(smiles)
  if mol is None:
    # return an empty fingerprint if the SMILES is invalid
    return DataStructs.cDataStructs.ExplicitBitVect(nBits)
  else:
    return mfpgen.GetFingerprint(mol)

with multiprocessing.Pool() as pool:
    arr = pool.map(smiles_to_fp, smiles)
# Out:
# [11:37:19] Explicit valence for atom # 2 O, 2, is greater than permitted
# [11:37:19] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [11:37:19] Explicit valence for atom # 0 B, 4, is greater than permitted
# [11:37:19] Explicit valence for atom # 0 B, 4, is greater than permitted
# [11:37:20] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [11:37:21] Conflicting single bond directions around double bond at index 6.
# [11:37:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:21] Explicit valence for atom # 10 O, 2, is greater than permitted
# [11:37:21] Conflicting single bond directions around double bond at index 3.
# [11:37:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:22] Conflicting single bond directions around double bond at index 8.
# [11:37:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:22] Conflicting single bond directions around double bond at index 8.
# [11:37:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:22] Conflicting single bond directions around double bond at index 7.
# [11:37:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:23] Conflicting single bond directions around double bond at index 3.
# [11:37:23]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:25] Conflicting single bond directions around double bond at index 3.
# [11:37:25]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:25] Conflicting single bond directions around double bond at index 12.
# [11:37:25]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:26] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [11:37:29] Conflicting single bond directions around double bond at index 3.
# [11:37:29]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:30] Conflicting single bond directions around double bond at index 6.
# [11:37:30]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:33] Conflicting single bond directions around double bond at index 1.
# [11:37:33]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:33] Conflicting single bond directions around double bond at index 3.
# [11:37:33]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:34] Conflicting single bond directions around double bond at index 3.
# [11:37:34]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:35] Conflicting single bond directions around double bond at index 5.
# [11:37:35]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:37] Conflicting single bond directions around double bond at index 7.
# [11:37:37]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:39] Conflicting single bond directions around double bond at index 14.
# [11:37:39]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:43] Conflicting single bond directions around double bond at index 7.
# [11:37:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:43] Conflicting single bond directions around double bond at index 13.
# [11:37:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:43] Conflicting single bond directions around double bond at index 3.
# [11:37:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:37:54] Conflicting single bond directions around double bond at index 7.
# [11:37:54]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:38:01] Conflicting single bond directions around double bond at index 14.
# [11:38:01]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:38:32] Conflicting single bond directions around double bond at index 5.
# [11:38:32]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:38:32] Conflicting single bond directions around double bond at index 14.
# [11:38:32]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:38:33] Conflicting single bond directions around double bond at index 4.
# [11:38:33]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:38:40] Conflicting single bond directions around double bond at index 6.
# [11:38:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:38:52] Conflicting single bond directions around double bond at index 13.
# [11:38:52]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:03] Conflicting single bond directions around double bond at index 6.
# [11:39:03]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:05] Conflicting single bond directions around double bond at index 2.
# [11:39:05]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:10] Conflicting single bond directions around double bond at index 24.
# [11:39:10] Conflicting single bond directions around double bond at index 16.
# [11:39:10]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:10]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:14] Conflicting single bond directions around double bond at index 5.
# [11:39:14]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:15] Conflicting single bond directions around double bond at index 10.
# [11:39:15]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:16] Conflicting single bond directions around double bond at index 5.
# [11:39:16]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:30] Conflicting single bond directions around double bond at index 27.
# [11:39:30]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:38] Conflicting single bond directions around double bond at index 9.
# [11:39:38]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:39] Conflicting single bond directions around double bond at index 11.
# [11:39:39]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:40] Conflicting single bond directions around double bond at index 11.
# [11:39:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:40] Conflicting single bond directions around double bond at index 29.
# [11:39:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:40] Conflicting single bond directions around double bond at index 11.
# [11:39:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:40] Conflicting single bond directions around double bond at index 11.
# [11:39:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:40] Conflicting single bond directions around double bond at index 19.
# [11:39:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:43] Conflicting single bond directions around double bond at index 3.
# [11:39:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:43] Conflicting single bond directions around double bond at index 17.
# [11:39:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:48] Conflicting single bond directions around double bond at index 11.
# [11:39:48]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:50] Conflicting single bond directions around double bond at index 17.
# [11:39:50]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:51] Conflicting single bond directions around double bond at index 12.
# [11:39:51]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:54] Conflicting single bond directions around double bond at index 11.
# [11:39:54]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:56] Conflicting single bond directions around double bond at index 17.
# [11:39:56]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:56] Conflicting single bond directions around double bond at index 11.
# [11:39:56]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:56] Conflicting single bond directions around double bond at index 11.
# [11:39:56]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:56] Conflicting single bond directions around double bond at index 11.
# [11:39:56]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:58] Conflicting single bond directions around double bond at index 11.
# [11:39:58]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:58] Conflicting single bond directions around double bond at index 11.
# [11:39:58]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:39:59] Conflicting single bond directions around double bond at index 11.
# [11:39:59]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:01] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [11:40:16] Conflicting single bond directions around double bond at index 11.
# [11:40:16]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:18] Conflicting single bond directions around double bond at index 13.
# [11:40:18]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:19] Conflicting single bond directions around double bond at index 11.
# [11:40:19]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:19] Conflicting single bond directions around double bond at index 11.
# [11:40:19]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:21] Conflicting single bond directions around double bond at index 11.
# [11:40:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:21] Conflicting single bond directions around double bond at index 11.
# [11:40:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:22] Conflicting single bond directions around double bond at index 11.
# [11:40:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:22] Conflicting single bond directions around double bond at index 11.
# [11:40:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [11:40:32] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [11:41:00] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.

# %%
assert len(arr) == len(smiles)

# %%
thresh = 0.65 # <- minimum distance between cluster centroids. random threshold for morgan radius 2 is 0.65

print(f"Finished computing fingerprints, clustering {len(arr)} molecules...")

lp = rdSimDivPickers.LeaderPicker()

picks = lp.LazyBitVectorPick(arr,len(arr),thresh)
# Out:
# 0 C1=CC(=C(C=C1Cl)Cl)Cl
# Finished computing fingerprints, clustering 10 molecules...

# %%
# with open('cluster_labels.txt', 'w') as f:
#     for i in picks:
#         smiles = table['smiles'][i].as_py()
#         iupac = table['iupac'][i].as_py()
#         cid = table['cid'][i].as_py()
#         formula = table['formula'][i].as_py()
#         num_atoms = table['num_atoms'][i].as_py()
#         # f.write(f"{smiles}\t{iupac}\t{labels[i]}\n")
#         f.write(f"{cid}\t{smiles}\t{iupac}\t{formula}\t{num_atoms}\n")

def convert_string_view_to_string(table):
    for column in table.schema:
        if pa.types.is_string_view(column.type):
            # Recreate the column as pa.string
            table = table.set_column(
                table.schema.get_field_index(column.name),
                column.name,
                pa.array(table[column.name].to_pylist(), type=pa.string())
            )
    return table

table = table.take(pa.array(picks))

# huggingface only supports string, not string_view
table = convert_string_view_to_string(table)

with pa.OSFile('/home/lyg/data/pubchem/arrow/pubchem_best_cluster.arrow', 'wb') as sink:
    with pa.RecordBatchFileWriter(sink, table.schema) as writer:
        writer.write_table(table)
print(f"Finished writing {len(picks)} picks to pubchem_best_cluster.arrow")
# Out:
# Finished writing 8 picks to pubchem_best_cluster.arrow
