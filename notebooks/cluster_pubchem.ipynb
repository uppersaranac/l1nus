# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import rdFingerprintGenerator
import pyarrow as pa
from rdkit.SimDivFilters import rdSimDivPickers
import multiprocessing

# %%
#in_memory_stream = pa.input_stream('/home/lyg/data/pubchem/arrow/pubchem_sorted.arrow')
#opened_stream = pa.ipc.open_stream(in_memory_stream)
#table = opened_stream.read_all()

table = pa.ipc.RecordBatchFileReader(pa.memory_map('/home/lyg/data/pubchem/arrow/pubchem_best.arrow')).read_all()

# write out the smiles to a temporary file
smiles = table.column('smiles').to_pylist()

smiles[0]
# Out:
# 'N'

# %%
radius=2
nBits=2048

mfpgen = rdFingerprintGenerator.GetMorganGenerator(radius=radius,fpSize=nBits)

def smiles_to_fp(smiles):
  """
  Worker function to create an RDKit fingerprint from a SMILES string.
  """
  mol = Chem.MolFromSmiles(smiles)
  if mol is None:
    # return an empty fingerprint if the SMILES is invalid
    return DataStructs.cDataStructs.ExplicitBitVect(nBits)
  else:
    return mfpgen.GetFingerprint(mol)

with multiprocessing.Pool() as pool:
    arr = pool.map(smiles_to_fp, smiles)
# Out:
# [16:29:56] Explicit valence for atom # 0 B, 4, is greater than permitted
# [16:29:57] Explicit valence for atom # 2 O, 2, is greater than permitted
# [16:29:57] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:29:58] Explicit valence for atom # 0 B, 4, is greater than permitted
# [16:29:58] Explicit valence for atom # 0 B, 4, is greater than permitted
# [16:29:59] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:29:59] Conflicting single bond directions around double bond at index 6.
# [16:29:59]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:00] Explicit valence for atom # 10 O, 2, is greater than permitted
# [16:30:00] Conflicting single bond directions around double bond at index 3.
# [16:30:00]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:00] Conflicting single bond directions around double bond at index 8.
# [16:30:00]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:00] Conflicting single bond directions around double bond at index 8.
# [16:30:00]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:01] Conflicting single bond directions around double bond at index 7.
# [16:30:01]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:03] Conflicting single bond directions around double bond at index 3.
# [16:30:03]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:03] Conflicting single bond directions around double bond at index 3.
# [16:30:03]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:04] Conflicting single bond directions around double bond at index 12.
# [16:30:04]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:05] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:30:09] Conflicting single bond directions around double bond at index 3.
# [16:30:09]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:09] Conflicting single bond directions around double bond at index 6.
# [16:30:09]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:12] Conflicting single bond directions around double bond at index 1.
# [16:30:12]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:12] Conflicting single bond directions around double bond at index 3.
# [16:30:12]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:13] Conflicting single bond directions around double bond at index 3.
# [16:30:13]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:14] Conflicting single bond directions around double bond at index 5.
# [16:30:14]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:17] Conflicting single bond directions around double bond at index 7.
# [16:30:17]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:18] Conflicting single bond directions around double bond at index 14.
# [16:30:18]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:21] Conflicting single bond directions around double bond at index 13.
# [16:30:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:21] Conflicting single bond directions around double bond at index 3.
# [16:30:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:22] Conflicting single bond directions around double bond at index 7.
# [16:30:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:32] Conflicting single bond directions around double bond at index 7.
# [16:30:32]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:30:38] Conflicting single bond directions around double bond at index 14.
# [16:30:38]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:09] Conflicting single bond directions around double bond at index 5.
# [16:31:09]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:11] Conflicting single bond directions around double bond at index 4.
# [16:31:11]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:11] Conflicting single bond directions around double bond at index 14.
# [16:31:11]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:16] Conflicting single bond directions around double bond at index 6.
# [16:31:16]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:31] Conflicting single bond directions around double bond at index 13.
# [16:31:31]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:40] Conflicting single bond directions around double bond at index 6.
# [16:31:40]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:43] Conflicting single bond directions around double bond at index 2.
# [16:31:43]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:49] Conflicting single bond directions around double bond at index 24.
# [16:31:49]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:50] Conflicting single bond directions around double bond at index 16.
# [16:31:50]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:52] Conflicting single bond directions around double bond at index 5.
# [16:31:52]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:52] Conflicting single bond directions around double bond at index 5.
# [16:31:52]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:31:53] Conflicting single bond directions around double bond at index 10.
# [16:31:53]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:07] Conflicting single bond directions around double bond at index 27.
# [16:32:07]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:15] Conflicting single bond directions around double bond at index 19.
# [16:32:15]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:17] Conflicting single bond directions around double bond at index 9.
# [16:32:17]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:18] Conflicting single bond directions around double bond at index 29.
# [16:32:18]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:19] Conflicting single bond directions around double bond at index 11.
# [16:32:19]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:21] Conflicting single bond directions around double bond at index 11.
# [16:32:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:21] Conflicting single bond directions around double bond at index 11.
# [16:32:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:21] Conflicting single bond directions around double bond at index 11.
# [16:32:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:21] Conflicting single bond directions around double bond at index 17.
# [16:32:21]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:22] Conflicting single bond directions around double bond at index 3.
# [16:32:22]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:24] Conflicting single bond directions around double bond at index 11.
# [16:32:24]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:27] Conflicting single bond directions around double bond at index 17.
# [16:32:27]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:30] Conflicting single bond directions around double bond at index 12.
# [16:32:30]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:31] Conflicting single bond directions around double bond at index 11.
# [16:32:31]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:31] Conflicting single bond directions around double bond at index 11.
# [16:32:31]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:31] Conflicting single bond directions around double bond at index 11.
# [16:32:31]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:31] Conflicting single bond directions around double bond at index 17.
# [16:32:31]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:35] Conflicting single bond directions around double bond at index 11.
# [16:32:35]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:36] Conflicting single bond directions around double bond at index 11.
# [16:32:36]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:36] Conflicting single bond directions around double bond at index 11.
# [16:32:36]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:37] Conflicting single bond directions around double bond at index 11.
# [16:32:37]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:37] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:32:55] Conflicting single bond directions around double bond at index 11.
# [16:32:55]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:55] Conflicting single bond directions around double bond at index 11.
# [16:32:55]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:56] Conflicting single bond directions around double bond at index 13.
# [16:32:56]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:56] Conflicting single bond directions around double bond at index 11.
# [16:32:56]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:59] Conflicting single bond directions around double bond at index 11.
# [16:32:59]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:32:59] Conflicting single bond directions around double bond at index 11.
# [16:32:59]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:33:00] Conflicting single bond directions around double bond at index 11.
# [16:33:00]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:33:00] Conflicting single bond directions around double bond at index 11.
# [16:33:00]   BondStereo set to STEREONONE and single bond directions set to NONE.
# [16:33:12] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.
# [16:33:36] WARNING: could not find number of expected rings. Switching to an approximate ring finding algorithm.

# %%
assert len(arr) == len(smiles) == table.num_rows

# %%
thresh = 0.6
# minimum distance between cluster centroids. random threshold for morgan radius 2 is 0.65
# see https://greglandrum.github.io/rdkit-blog/posts/2020-11-18-sphere-exclusion-clustering.html#decreasing-the-sphere-radius

print(f"Finished computing fingerprints, clustering {len(arr)} molecules...")

lp = rdSimDivPickers.LeaderPicker()

picks = lp.LazyBitVectorPick(arr,len(arr),thresh)
# Out:
# Finished computing fingerprints, clustering 16588727 molecules...

# %%
# with open('cluster_labels.txt', 'w') as f:
#     for i in picks:
#         smiles = table['smiles'][i].as_py()
#         iupac = table['iupac'][i].as_py()
#         cid = table['cid'][i].as_py()
#         formula = table['formula'][i].as_py()
#         num_atoms = table['num_atoms'][i].as_py()
#         # f.write(f"{smiles}\t{iupac}\t{labels[i]}\n")
#         f.write(f"{cid}\t{smiles}\t{iupac}\t{formula}\t{num_atoms}\n")

def convert_string_view_to_string(table):
    for column in table.schema:
        if pa.types.is_string_view(column.type):
            # Recreate the column as pa.string
            table = table.set_column(
                table.schema.get_field_index(column.name),
                column.name,
                pa.array(table[column.name].to_pylist(), type=pa.string())
            )
    return table

table2 = table.take(pa.array(picks))

# huggingface only supports string, not string_view
table2 = convert_string_view_to_string(table2)

with pa.OSFile('/home/lyg/data/pubchem/arrow/pubchem_best_cluster.arrow', 'wb') as sink:
    with pa.RecordBatchFileWriter(sink, table2.schema) as writer:
        writer.write_table(table2)
print(f"Finished writing {len(picks)} picks to pubchem_best_cluster.arrow")
# Out:
# Finished writing 839175 picks to pubchem_best_cluster.arrow

# %%
ipicks = list(picks)

# %%
with open('/home/lyg/data/pubchem/arrow/pubchem_best_cluster_picks.txt', 'w') as f:   
    for i in ipicks:
        f.write(f"{i}\n")

# %%
len(table2)
# Out:
# 839175
